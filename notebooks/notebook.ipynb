# %%
# Check the statistics of key columns

# %%
import re
import glob
import statistics
import numpy as np
import pandas as pd
import pm4py
from random import sample
from itertools import product
from collections import Counter
from SetSimilaritySearch import all_pairs

# %%
def load_event_log(dataset_path=None, n_rows=1000):
    print('Reading', dataset_path)
    try:
        event_log = pd.read_csv(dataset_path, nrows=n_rows)
    except:
        return None
    h = event_log.columns.values.tolist()
    # check if a dataset contains a tuple of case_id, activity, and timestamp
    if ('case:concept:name' in h) and ('concept:name' in h) and ('time:timestamp' in h):
        # pre-process an event log
        return event_log.fillna(np.nan).replace([np.nan], [''])
    else:
        return None

# %%
datasets = glob.glob('../datasets/*.csv', recursive=False)
event_logs = [load_event_log(d, n_rows=1000) for d in datasets]
# remove None from event_logs
event_logs = [e for e in event_logs if e is not None]
print('Datasets found in the dataset dir:', len(datasets))
print('Datasets that are ready for evaluation:', len(event_logs))
# Out:
# Reading ../datasets/BPIC2015_2.csv
# Reading ../datasets/BPIC2013_incident_management.csv
# Reading ../datasets/BPIC2020_Prepaid_Travel_Costs.csv
# Reading ../datasets/BPIC2018.csv
# Reading ../datasets/BPIC2013_problem_management_open_problems.csv
# Reading ../datasets/BPIC2016_Clicks_NOT_Logged_In.csv
# Reading ../datasets/BPIC2015_5.csv
# Reading ../datasets/BPIC2015_4.csv
# Reading ../datasets/BPIC2016_Clicks_Logged_In.csv
# Reading ../datasets/BPIC2014_change_log.csv
# Reading ../datasets/BPIC2011_Dutch_academic_hospital.csv
# Reading ../datasets/BPIC2017.csv
# Reading ../datasets/BPIC2013_problem_management_closed_problems.csv
# Reading ../datasets/tmp.csv
# Reading ../datasets/BPIC2015_3.csv
# Reading ../datasets/test.csv
# Reading ../datasets/BPIC2012_loan_application_process.csv
# Reading ../datasets/BPIC2019_purchase_order_handling_process.csv
# Reading ../datasets/BPI2016_Clicks_Logged_In.csv
# Reading ../datasets/BPIC2015_1.csv
# Reading ../datasets/BPI2016_Clicks_NOT_Logged_In.csv
# Datasets found in the dataset dir: 21
# Datasets that are ready for evaluation: 14

# %%
# check number of unique values
[event_logs[e].apply(lambda x: statistics.mean(Counter(x).values()), axis=0) for e in range(len(event_logs))]
# Out:
# [monitoringResource         200.000000
#  org:resource               166.666667
#  activityNameNL               7.936508
#  concept:name                 7.042254
#  question                    37.037037
#  dateFinished                 7.751938
#  action_code                  7.042254
#  activityNameEN               7.936508
#  planned                      2.114165
#  lifecycle:transition      1000.000000
#  time:timestamp               1.972387
#  case:Includes_subCases     500.000000
#  case:concept:name           55.555556
#  case:Responsible_actor     250.000000
#  case:endDate                58.823529
#  case:caseStatus           1000.000000
#  case:parts                 111.111111
#  case:caseProcedure         500.000000
#  case:last_phase           1000.000000
#  case:case_type            1000.000000
#  case:startDate              66.666667
#  case:requestComplete       500.000000
#  case:SUMleges               71.428571
#  case:IDofConceptCase       200.000000
#  case:termName              500.000000
#  case:landRegisterID       1000.000000
#  dueDate                   1000.000000
#  dateStop                  1000.000000
#  dtype: float64,
#  org:group                 17.543860
#  resource country          76.923077
#  organization country     142.857143
#  org:resource               9.433962
#  organization involved    111.111111
#  org:role                  90.909091
#  concept:name             333.333333
#  impact                   333.333333
#  product                   47.619048
#  lifecycle:transition     100.000000
#  time:timestamp             1.019368
#  case:concept:name         19.607843
#  dtype: float64,
#  id                                     1.124859
#  org:resource                         500.000000
#  concept:name                          47.619048
#  time:timestamp                         1.250000
#  org:role                             166.666667
#  case:Rfp_id                            7.751938
#  case:Permit travel permit number      12.195122
#  case:Task                             20.000000
#  case:OrganizationalEntity            200.000000
#  case:RequestedAmount                   8.064516
#  case:Activity                        333.333333
#  case:Permit TaskNumber               333.333333
#  case:Permit BudgetNumber              37.037037
#  case:Permit ProjectNumber             21.739130
#  case:Project                         500.000000
#  case:concept:name                      7.751938
#  case:Permit OrganizationalEntity     250.000000
#  case:Permit RequestedBudget           11.627907
#  case:Cost Type                      1000.000000
#  case:Permit id                        11.363636
#  case:Permit ActivityNumber           200.000000
#  case:RfpNumber                         7.812500
#  dtype: float64,
#  success                 1000.000000
#  org:resource              22.222222
#  docid_uuid                 8.695652
#  doctype                  142.857143
#  subprocess               250.000000
#                             ...
#  case:payment_actual2    1000.000000
#  case:amount_applied2    1000.000000
#  case:penalty_amount3    1000.000000
#  case:payment_actual3    1000.000000
#  case:amount_applied3    1000.000000
#  Length: 75, dtype: float64,
#  org:group               142.857143
#  resource country        111.111111
#  org:resource              9.009009
#  oranization country     111.111111
#  org:role                 45.454545
#  concept:name            333.333333
#  impact                  250.000000
#  product                  15.873016
#  time:timestamp            1.002004
#  lifecycle:transition    200.000000
#  case:concept:name         3.246753
#  dtype: float64,
#  question                    62.500000
#  dateFinished                20.833333
#  dueDate                     27.027027
#  action_code                  7.352941
#  activityNameEN               8.130081
#  planned                      1.792115
#  time:timestamp               9.009009
#  monitoringResource         111.111111
#  org:resource               111.111111
#  activityNameNL               8.130081
#  concept:name                 7.352941
#  lifecycle:transition      1000.000000
#  case:endDate                76.923077
#  case:caseStatus            500.000000
#  case:SUMleges               83.333333
#  case:last_phase            166.666667
#  case:case_type            1000.000000
#  case:concept:name           55.555556
#  case:Responsible_actor     142.857143
#  case:landRegisterID         55.555556
#  case:parts                 125.000000
#  case:termName              333.333333
#  case:startDate              62.500000
#  case:requestComplete       500.000000
#  case:IDofConceptCase        76.923077
#  case:caseProcedure         333.333333
#  case:Includes_subCases    1000.000000
#  case:endDatePlanned       1000.000000
#  dateStop                  1000.000000
#  dtype: float64,
#  question                    83.333333
#  dateFinished                22.727273
#  dueDate                     20.000000
#  action_code                  9.523810
#  activityNameEN              10.416667
#  planned                      1.988072
#  time:timestamp               9.345794
#  monitoringResource         166.666667
#  org:resource               200.000000
#  activityNameNL              10.416667
#  concept:name                 9.523810
#  lifecycle:transition      1000.000000
#  case:concept:name           41.666667
#  case:Responsible_actor     250.000000
#  case:endDate                71.428571
#  case:caseStatus            500.000000
#  case:parts                 166.666667
#  case:SUMleges               58.823529
#  case:last_phase            200.000000
#  case:case_type            1000.000000
#  case:startDate              58.823529
#  case:requestComplete       500.000000
#  case:IDofConceptCase        55.555556
#  case:termName              200.000000
#  case:caseProcedure         500.000000
#  case:landRegisterID        333.333333
#  case:Includes_subCases    1000.000000
#  dateStop                  1000.000000
#  case:endDatePlanned       1000.000000
#  dtype: float64,
#  org:group                   71.428571
#  Number of executions      1000.000000
#  Specialism code            100.000000
#  concept:name                 7.462687
#  Producer code               31.250000
#                               ...
#  case:Diagnosis:13         1000.000000
#  case:Diagnosis:12         1000.000000
#  case:Diagnosis code:14    1000.000000
#  case:Diagnosis code:13    1000.000000
#  case:Diagnosis code:15    1000.000000
#  Length: 128, dtype: float64,
#  Action                    200.000000
#  org:resource               23.255814
#  concept:name               43.478261
#  EventOrigin               333.333333
#  EventID                     1.000000
#  lifecycle:transition      142.857143
#  time:timestamp              1.000000
#  case:LoanGoal             166.666667
#  case:ApplicationType     1000.000000
#  case:concept:name          34.482759
#  case:RequestedAmount       66.666667
#  FirstWithdrawalAmount      50.000000
#  NumberOfTerms              41.666667
#  Accepted                  333.333333
#  MonthlyCost                27.777778
#  Selected                  333.333333
#  CreditScore                76.923077
#  OfferedAmount              50.000000
#  OfferID                    23.809524
#  dtype: float64,
#  org:group                100.000000
#  resource country          83.333333
#  organization country     111.111111
#  org:resource               8.130081
#  organization involved     14.285714
#  org:role                  55.555556
#  concept:name             250.000000
#  impact                   250.000000
#  product                   16.393443
#  lifecycle:transition     166.666667
#  time:timestamp             1.002004
#  case:concept:name          6.329114
#  dtype: float64,
#  question                    40.000000
#  dateFinished                 5.128205
#  dueDate                      7.812500
#  action_code                 10.309278
#  activityNameEN              11.235955
#  planned                      1.267427
#  time:timestamp               1.204819
#  monitoringResource         111.111111
#  org:resource               111.111111
#  activityNameNL              11.235955
#  concept:name                10.309278
#  lifecycle:transition      1000.000000
#  case:Includes_subCases     500.000000
#  case:concept:name           35.714286
#  case:Responsible_actor     166.666667
#  case:caseStatus           1000.000000
#  case:last_phase            166.666667
#  case:case_type            1000.000000
#  case:termName              200.000000
#  case:startDate              62.500000
#  case:requestComplete      1000.000000
#  case:endDate                58.823529
#  case:parts                 100.000000
#  case:SUMleges              111.111111
#  case:caseProcedure         333.333333
#  case:IDofConceptCase        90.909091
#  case:endDatePlanned        500.000000
#  dateStop                  1000.000000
#  case:landRegisterID       1000.000000
#  dtype: float64,
#  org:resource             25.641026
#  lifecycle:transition    333.333333
#  concept:name             41.666667
#  time:timestamp            1.060445
#  case:REG_DATE            27.027027
#  case:concept:name        27.027027
#  case:AMOUNT_REQ          55.555556
#  dtype: float64,
#  User                                41.666667
#  org:resource                        41.666667
#  concept:name                        47.619048
#  Cumulative net worth (EUR)          43.478261
#  time:timestamp                       1.801802
#  case:Spend area text               250.000000
#  case:Company                      1000.000000
#  case:Document Type                1000.000000
#  case:Sub spend area text           100.000000
#  case:Purchasing Document            50.000000
#  case:Purch. Doc. Category name    1000.000000
#  case:Vendor                         55.555556
#  case:Item Type                     500.000000
#  case:Item Category                 500.000000
#  case:Spend classification text    1000.000000
#  case:Source                       1000.000000
#  case:Name                           55.555556
#  case:GR-Based Inv. Verif.          500.000000
#  case:Item                          333.333333
#  case:concept:name                   43.478261
#  case:Goods Receipt                1000.000000
#  dtype: float64,
#  question                    66.666667
#  dateFinished                21.276596
#  dueDate                     24.390244
#  action_code                  9.009009
#  activityNameEN              10.416667
#  planned                      1.245330
#  time:timestamp              10.869565
#  monitoringResource         125.000000
#  org:resource               142.857143
#  activityNameNL              10.416667
#  concept:name                 9.009009
#  lifecycle:transition      1000.000000
#  case:endDate               111.111111
#  case:caseStatus            500.000000
#  case:SUMleges               71.428571
#  case:last_phase            200.000000
#  case:case_type            1000.000000
#  case:concept:name           50.000000
#  case:Responsible_actor     200.000000
#  case:parts                 111.111111
#  case:termName              250.000000
#  case:endDatePlanned        142.857143
#  case:startDate              66.666667
#  case:requestComplete       500.000000
#  case:IDofConceptCase        62.500000
#  case:landRegisterID        250.000000
#  case:caseProcedure         500.000000
#  case:Includes_subCases    1000.000000
#  dateStop                  1000.000000
#  dtype: float64]

# %%
# check number of unique values
[event_logs[e].apply(lambda x: len(set(x)), axis=0) for e in range(len(event_logs))]
# Out:
# [monitoringResource          5
#  org:resource                6
#  activityNameNL            126
#  concept:name              142
#  question                   27
#  dateFinished              129
#  action_code               142
#  activityNameEN            126
#  planned                   473
#  lifecycle:transition        1
#  time:timestamp            507
#  case:Includes_subCases      2
#  case:concept:name          18
#  case:Responsible_actor      4
#  case:endDate               17
#  case:caseStatus             1
#  case:parts                  9
#  case:caseProcedure          2
#  case:last_phase             1
#  case:case_type              1
#  case:startDate             15
#  case:requestComplete        2
#  case:SUMleges              14
#  case:IDofConceptCase        5
#  case:termName               2
#  case:landRegisterID         1
#  dueDate                     1
#  dateStop                    1
#  dtype: int64,
#  org:group                 57
#  resource country          13
#  organization country       7
#  org:resource             106
#  organization involved      9
#  org:role                  11
#  concept:name               3
#  impact                     3
#  product                   21
#  lifecycle:transition      10
#  time:timestamp           981
#  case:concept:name         51
#  dtype: int64,
#  success                   1
#  org:resource             45
#  docid_uuid              115
#  doctype                   7
#  subprocess                4
#                         ...
#  case:payment_actual2      1
#  case:amount_applied2      1
#  case:penalty_amount3      1
#  case:payment_actual3      1
#  case:amount_applied3      1
#  Length: 75, dtype: int64,
#  org:group                 7
#  resource country          9
#  org:resource            111
#  oranization country       9
#  org:role                 22
#  concept:name              3
#  impact                    4
#  product                  63
#  time:timestamp          998
#  lifecycle:transition      5
#  case:concept:name       308
#  dtype: int64,
#  question                   16
#  dateFinished               48
#  dueDate                    37
#  action_code               136
#  activityNameEN            123
#  planned                   558
#  time:timestamp            111
#  monitoringResource          9
#  org:resource                9
#  activityNameNL            123
#  concept:name              136
#  lifecycle:transition        1
#  case:endDate               13
#  case:caseStatus             2
#  case:SUMleges              12
#  case:last_phase             6
#  case:case_type              1
#  case:concept:name          18
#  case:Responsible_actor      7
#  case:landRegisterID        18
#  case:parts                  8
#  case:termName               3
#  case:startDate             16
#  case:requestComplete        2
#  case:IDofConceptCase       13
#  case:caseProcedure          3
#  case:Includes_subCases      1
#  case:endDatePlanned         1
#  dateStop                    1
#  dtype: int64,
#  question                   12
#  dateFinished               44
#  dueDate                    50
#  action_code               105
#  activityNameEN             96
#  planned                   503
#  time:timestamp            107
#  monitoringResource          6
#  org:resource                5
#  activityNameNL             96
#  concept:name              105
#  lifecycle:transition        1
#  case:concept:name          24
#  case:Responsible_actor      4
#  case:endDate               14
#  case:caseStatus             2
#  case:parts                  6
#  case:SUMleges              17
#  case:last_phase             5
#  case:case_type              1
#  case:startDate             17
#  case:requestComplete        2
#  case:IDofConceptCase       18
#  case:termName               5
#  case:caseProcedure          2
#  case:landRegisterID         3
#  case:Includes_subCases      1
#  dateStop                    1
#  case:endDatePlanned         1
#  dtype: int64,
#  org:group                  14
#  Number of executions        1
#  Specialism code            10
#  concept:name              134
#  Producer code              32
#                           ...
#  case:Diagnosis:13           1
#  case:Diagnosis:12           1
#  case:Diagnosis code:14      1
#  case:Diagnosis code:13      1
#  case:Diagnosis code:15      1
#  Length: 128, dtype: int64,
#  Action                      5
#  org:resource               43
#  concept:name               23
#  EventOrigin                 3
#  EventID                  1000
#  lifecycle:transition        7
#  time:timestamp           1000
#  case:LoanGoal               6
#  case:ApplicationType        1
#  case:concept:name          29
#  case:RequestedAmount       15
#  FirstWithdrawalAmount      20
#  NumberOfTerms              24
#  Accepted                    3
#  MonthlyCost                36
#  Selected                    3
#  CreditScore                13
#  OfferedAmount              20
#  OfferID                    42
#  dtype: int64,
#  org:group                 10
#  resource country          12
#  organization country       9
#  org:resource             123
#  organization involved     70
#  org:role                  18
#  concept:name               4
#  impact                     4
#  product                   61
#  lifecycle:transition       6
#  time:timestamp           998
#  case:concept:name        158
#  dtype: int64,
#  question                   25
#  dateFinished              195
#  dueDate                   128
#  action_code                97
#  activityNameEN             89
#  planned                   789
#  time:timestamp            830
#  monitoringResource          9
#  org:resource                9
#  activityNameNL             89
#  concept:name               97
#  lifecycle:transition        1
#  case:Includes_subCases      2
#  case:concept:name          28
#  case:Responsible_actor      6
#  case:caseStatus             1
#  case:last_phase             6
#  case:case_type              1
#  case:termName               5
#  case:startDate             16
#  case:requestComplete        1
#  case:endDate               17
#  case:parts                 10
#  case:SUMleges               9
#  case:caseProcedure          3
#  case:IDofConceptCase       11
#  case:endDatePlanned         2
#  dateStop                    1
#  case:landRegisterID         1
#  dtype: int64,
#  org:resource             39
#  lifecycle:transition      3
#  concept:name             24
#  time:timestamp          943
#  case:REG_DATE            37
#  case:concept:name        37
#  case:AMOUNT_REQ          18
#  dtype: int64,
#  User                               24
#  org:resource                       24
#  concept:name                       21
#  Cumulative net worth (EUR)         23
#  time:timestamp                    555
#  case:Spend area text                4
#  case:Company                        1
#  case:Document Type                  1
#  case:Sub spend area text           10
#  case:Purchasing Document           20
#  case:Purch. Doc. Category name      1
#  case:Vendor                        18
#  case:Item Type                      2
#  case:Item Category                  2
#  case:Spend classification text      1
#  case:Source                         1
#  case:Name                          18
#  case:GR-Based Inv. Verif.           2
#  case:Item                           3
#  case:concept:name                  23
#  case:Goods Receipt                  1
#  dtype: int64,
#  question                   15
#  dateFinished               47
#  dueDate                    41
#  action_code               111
#  activityNameEN             96
#  planned                   803
#  time:timestamp             92
#  monitoringResource          8
#  org:resource                7
#  activityNameNL             96
#  concept:name              111
#  lifecycle:transition        1
#  case:endDate                9
#  case:caseStatus             2
#  case:SUMleges              14
#  case:last_phase             5
#  case:case_type              1
#  case:concept:name          20
#  case:Responsible_actor      5
#  case:parts                  9
#  case:termName               4
#  case:endDatePlanned         7
#  case:startDate             15
#  case:requestComplete        2
#  case:IDofConceptCase       16
#  case:landRegisterID         4
#  case:caseProcedure          2
#  case:Includes_subCases      1
#  dateStop                    1
#  dtype: int64]

# %%
# what do activities look like?
[event_logs[e]['concept:name'] for e in range(len(event_logs))]
# Out:
# [0      01_HOOFD_010
#  1      01_HOOFD_011
#  2      01_HOOFD_020
#  3      01_HOOFD_015
#  4        03_GBH_005
#             ...
#  995       06_VD_010
#  996    01_HOOFD_101
#  997    01_HOOFD_130
#  998    01_HOOFD_110
#  999    01_HOOFD_180
#  Name: concept:name, Length: 1000, dtype: object,
#  0       Accepted
#  1       Accepted
#  2         Queued
#  3       Accepted
#  4         Queued
#           ...
#  995     Accepted
#  996     Accepted
#  997    Completed
#  998       Queued
#  999     Accepted
#  Name: concept:name, Length: 1000, dtype: object,
#  0         mail income
#  1          mail valid
#  2          mail valid
#  3          mail valid
#  4          initialize
#              ...
#  995     begin editing
#  996         calculate
#  997    finish editing
#  998     begin editing
#  999         calculate
#  Name: concept:name, Length: 1000, dtype: object,
#  0       Accepted
#  1       Accepted
#  2       Accepted
#  3       Accepted
#  4       Accepted
#           ...
#  995     Accepted
#  996    Completed
#  997     Accepted
#  998    Completed
#  999     Accepted
#  Name: concept:name, Length: 1000, dtype: object,
#  0        01_HOOFD_010
#  1        01_HOOFD_011
#  2        01_HOOFD_020
#  3          03_GBH_005
#  4         05_EIND_010
#              ...
#  995    01_HOOFD_490_2
#  996       14_VRIJ_010
#  997    01_HOOFD_110_0
#  998    01_HOOFD_250_2
#  999      01_HOOFD_370
#  Name: concept:name, Length: 1000, dtype: object,
#  0         01_HOOFD_010
#  1           04_BPT_005
#  2       01_HOOFD_065_0
#  3         01_HOOFD_090
#  4       01_HOOFD_110_0
#              ...
#  995     01_HOOFD_490_1
#  996       01_HOOFD_195
#  997    01_HOOFD_490_1a
#  998       01_HOOFD_491
#  999       01_HOOFD_500
#  Name: concept:name, Length: 1000, dtype: object,
#  0                       1e consult poliklinisch
#  1      administratief tarief       - eerste pol
#  2       verlosk.-gynaec. korte kaart kosten-out
#  3               echografie  - genitalia interna
#  4                       1e consult poliklinisch
#                           ...
#  995                                     calcium
#  996                                    albumine
#  997                                 ordertarief
#  998                 vervolgconsult poliklinisch
#  999    administratief tarief       - eerste pol
#  Name: concept:name, Length: 1000, dtype: object,
#  0        A_Create Application
#  1                 A_Submitted
#  2              W_Handle leads
#  3              W_Handle leads
#  4      W_Complete application
#                  ...
#  995               A_Submitted
#  996            W_Handle leads
#  997            W_Handle leads
#  998            W_Handle leads
#  999    W_Complete application
#  Name: concept:name, Length: 1000, dtype: object,
#  0         Queued
#  1       Accepted
#  2       Accepted
#  3       Accepted
#  4      Completed
#           ...
#  995       Queued
#  996     Accepted
#  997     Accepted
#  998     Accepted
#  999     Accepted
#  Name: concept:name, Length: 1000, dtype: object,
#  0        01_HOOFD_010
#  1      01_HOOFD_030_2
#  2        01_HOOFD_015
#  3        01_HOOFD_020
#  4      01_HOOFD_030_1
#              ...
#  995      01_HOOFD_250
#  996      01_HOOFD_260
#  997       09_AH_I_010
#  998      01_HOOFD_375
#  999      01_HOOFD_370
#  Name: concept:name, Length: 1000, dtype: object,
#  0                 A_SUBMITTED
#  1           A_PARTLYSUBMITTED
#  2               A_PREACCEPTED
#  3      W_Completeren aanvraag
#  4      W_Completeren aanvraag
#                  ...
#  995                 O_CREATED
#  996                    O_SENT
#  997       W_Nabellen offertes
#  998    W_Completeren aanvraag
#  999       W_Nabellen offertes
#  Name: concept:name, Length: 1000, dtype: object,
#  0                             SRM: Created
#  1                            SRM: Complete
#  2                   SRM: Awaiting Approval
#  3                  SRM: Document Completed
#  4      SRM: In Transfer to Execution Syst.
#                        ...
#  995                   Record Goods Receipt
#  996             Record Service Entry Sheet
#  997                 Record Invoice Receipt
#  998                 Vendor creates invoice
#  999                          Clear Invoice
#  Name: concept:name, Length: 1000, dtype: object,
#  0        01_HOOFD_010
#  1        01_HOOFD_011
#  2        01_HOOFD_020
#  3          02_DRZ_010
#  4          04_BPT_005
#              ...
#  995      01_HOOFD_375
#  996      01_HOOFD_495
#  997    01_HOOFD_490_4
#  998    01_HOOFD_510_2
#  999      08_AWB45_045
#  Name: concept:name, Length: 1000, dtype: object]

# %%
# How much unique activity appears?
[len(set(event_logs[e]['concept:name'])) / len(event_logs[e]['concept:name']) for e in range(len(event_logs))]
# Out:
# [0.142,
#  0.003,
#  0.021,
#  0.003,
#  0.136,
#  0.105,
#  0.134,
#  0.023,
#  0.004,
#  0.097,
#  0.024,
#  0.021,
#  0.111]

# %%
# what about case_id?
[len(set(event_logs[e]['case:concept:name'])) / len(event_logs[e]['case:concept:name']) for e in range(len(event_logs))]
# Out:
# [0.018,
#  0.051,
#  0.019,
#  0.308,
#  0.018,
#  0.024,
#  0.008,
#  0.029,
#  0.158,
#  0.028,
#  0.037,
#  0.023,
#  0.02]

# %%
# what about timestamp?
[len(set(event_logs[e]['time:timestamp'])) / len(event_logs[e]['time:timestamp']) for e in range(len(event_logs))]
# Out:
# [0.507,
#  0.981,
#  0.842,
#  0.998,
#  0.111,
#  0.107,
#  0.135,
#  1.0,
#  0.998,
#  0.83,
#  0.943,
#  0.555,
#  0.092]

# %%
def similarity_check(event_log_df=None, n_samples=100):
    n_cases = len(set(event_log_df['case:concept:name']))
    if n_cases > n_samples:
        # sample n_sample cases
        sampled_case_ids = sample(list(set(event_log_df['case:concept:name'])), n_samples)
        event_log_df = event_log_df[event_log_df['case:concept:name'].isin(sampled_case_ids)]
    
    # get the sequence of activities by case_ids
    sets = event_log_df.groupby('case:concept:name')['concept:name']\
        .apply(list).apply(set).tolist()
    if len(sets) > 0:
        pairs = list(all_pairs(sets, similarity_func_name="cosine", similarity_threshold=0.1))
        #  print('pairs:', pairs)
        if len(pairs) == 0:
            cosine_sim = 0
        else:
            cosine_sim = round(np.mean([list(pairs[i])[2] for i in range(len(pairs))]), ndigits=2)
    else:
        cosine_sim = 0

    return cosine_sim

# %%
[similarity_check(event_log_df=e) for e in event_logs]
# Out:
# [0.65, 0.98, 0.9, 0.82, 0.68, 0.75, 0.4, 0.81, 0.9, 0.64, 0.59, 0.89, 0.76]

# %%
[event_logs[e].apply(lambda x: any(x == ''), axis=0) for e in range(len(event_logs))]
# Out:
# [monitoringResource        False
#  org:resource              False
#  activityNameNL            False
#  concept:name              False
#  question                  False
#  dateFinished              False
#  action_code               False
#  activityNameEN            False
#  planned                    True
#  lifecycle:transition      False
#  time:timestamp            False
#  case:Includes_subCases    False
#  case:concept:name         False
#  case:Responsible_actor    False
#  case:endDate               True
#  case:caseStatus           False
#  case:parts                False
#  case:caseProcedure         True
#  case:last_phase           False
#  case:case_type            False
#  case:startDate            False
#  case:requestComplete      False
#  case:SUMleges              True
#  case:IDofConceptCase       True
#  case:termName              True
#  case:landRegisterID        True
#  dueDate                    True
#  dateStop                   True
#  dtype: bool,
#  org:group                False
#  resource country         False
#  organization country     False
#  org:resource             False
#  organization involved    False
#  org:role                  True
#  concept:name             False
#  impact                   False
#  product                  False
#  lifecycle:transition     False
#  time:timestamp           False
#  case:concept:name        False
#  dtype: bool,
#  success                 False
#  org:resource            False
#  docid_uuid              False
#  doctype                 False
#  subprocess              False
#                          ...
#  case:payment_actual2     True
#  case:amount_applied2     True
#  case:penalty_amount3     True
#  case:payment_actual3     True
#  case:amount_applied3     True
#  Length: 75, dtype: bool,
#  org:group               False
#  resource country        False
#  org:resource            False
#  oranization country     False
#  org:role                 True
#  concept:name            False
#  impact                  False
#  product                 False
#  time:timestamp          False
#  lifecycle:transition    False
#  case:concept:name       False
#  dtype: bool,
#  question                  False
#  dateFinished              False
#  dueDate                    True
#  action_code                True
#  activityNameEN            False
#  planned                    True
#  time:timestamp            False
#  monitoringResource        False
#  org:resource              False
#  activityNameNL            False
#  concept:name              False
#  lifecycle:transition      False
#  case:endDate               True
#  case:caseStatus           False
#  case:SUMleges              True
#  case:last_phase           False
#  case:case_type            False
#  case:concept:name         False
#  case:Responsible_actor    False
#  case:landRegisterID        True
#  case:parts                False
#  case:termName              True
#  case:startDate            False
#  case:requestComplete      False
#  case:IDofConceptCase       True
#  case:caseProcedure         True
#  case:Includes_subCases     True
#  case:endDatePlanned        True
#  dateStop                   True
#  dtype: bool,
#  question                  False
#  dateFinished              False
#  dueDate                    True
#  action_code                True
#  activityNameEN            False
#  planned                    True
#  time:timestamp            False
#  monitoringResource        False
#  org:resource              False
#  activityNameNL            False
#  concept:name              False
#  lifecycle:transition      False
#  case:concept:name         False
#  case:Responsible_actor    False
#  case:endDate               True
#  case:caseStatus           False
#  case:parts                False
#  case:SUMleges              True
#  case:last_phase           False
#  case:case_type            False
#  case:startDate            False
#  case:requestComplete      False
#  case:IDofConceptCase       True
#  case:termName              True
#  case:caseProcedure         True
#  case:landRegisterID        True
#  case:Includes_subCases     True
#  dateStop                   True
#  case:endDatePlanned        True
#  dtype: bool,
#  org:group                 False
#  Number of executions      False
#  Specialism code           False
#  concept:name              False
#  Producer code             False
#                            ...
#  case:Diagnosis:13          True
#  case:Diagnosis:12          True
#  case:Diagnosis code:14     True
#  case:Diagnosis code:13     True
#  case:Diagnosis code:15     True
#  Length: 128, dtype: bool,
#  Action                   False
#  org:resource             False
#  concept:name             False
#  EventOrigin              False
#  EventID                  False
#  lifecycle:transition     False
#  time:timestamp           False
#  case:LoanGoal            False
#  case:ApplicationType     False
#  case:concept:name        False
#  case:RequestedAmount     False
#  FirstWithdrawalAmount     True
#  NumberOfTerms             True
#  Accepted                  True
#  MonthlyCost               True
#  Selected                  True
#  CreditScore               True
#  OfferedAmount             True
#  OfferID                   True
#  dtype: bool,
#  org:group                False
#  resource country         False
#  organization country     False
#  org:resource             False
#  organization involved    False
#  org:role                  True
#  concept:name             False
#  impact                   False
#  product                  False
#  lifecycle:transition     False
#  time:timestamp           False
#  case:concept:name        False
#  dtype: bool,
#  question                  False
#  dateFinished              False
#  dueDate                    True
#  action_code               False
#  activityNameEN            False
#  planned                    True
#  time:timestamp            False
#  monitoringResource        False
#  org:resource              False
#  activityNameNL            False
#  concept:name              False
#  lifecycle:transition      False
#  case:Includes_subCases    False
#  case:concept:name         False
#  case:Responsible_actor    False
#  case:caseStatus           False
#  case:last_phase           False
#  case:case_type            False
#  case:termName              True
#  case:startDate            False
#  case:requestComplete      False
#  case:endDate               True
#  case:parts                 True
#  case:SUMleges              True
#  case:caseProcedure         True
#  case:IDofConceptCase       True
#  case:endDatePlanned        True
#  dateStop                   True
#  case:landRegisterID        True
#  dtype: bool,
#  org:resource             True
#  lifecycle:transition    False
#  concept:name            False
#  time:timestamp          False
#  case:REG_DATE           False
#  case:concept:name       False
#  case:AMOUNT_REQ         False
#  dtype: bool,
#  User                              False
#  org:resource                      False
#  concept:name                      False
#  Cumulative net worth (EUR)        False
#  time:timestamp                    False
#  case:Spend area text              False
#  case:Company                      False
#  case:Document Type                False
#  case:Sub spend area text          False
#  case:Purchasing Document          False
#  case:Purch. Doc. Category name    False
#  case:Vendor                       False
#  case:Item Type                    False
#  case:Item Category                False
#  case:Spend classification text    False
#  case:Source                       False
#  case:Name                         False
#  case:GR-Based Inv. Verif.         False
#  case:Item                         False
#  case:concept:name                 False
#  case:Goods Receipt                False
#  dtype: bool,
#  question                  False
#  dateFinished              False
#  dueDate                    True
#  action_code               False
#  activityNameEN            False
#  planned                   False
#  time:timestamp            False
#  monitoringResource        False
#  org:resource              False
#  activityNameNL            False
#  concept:name              False
#  lifecycle:transition      False
#  case:endDate               True
#  case:caseStatus           False
#  case:SUMleges              True
#  case:last_phase           False
#  case:case_type            False
#  case:concept:name         False
#  case:Responsible_actor    False
#  case:parts                False
#  case:termName              True
#  case:endDatePlanned        True
#  case:startDate            False
#  case:requestComplete      False
#  case:IDofConceptCase       True
#  case:landRegisterID        True
#  case:caseProcedure         True
#  case:Includes_subCases     True
#  dateStop                   True
#  dtype: bool]

# %%
event_logs[0]
# Out:
#      monitoringResource  org:resource                          activityNameNL  \
# 0               4634935        560530  registratie datum binnenkomst aanvraag
# 1               4634935        560530             OLO berichtenverkeer actief
# 2               4634935        560530          versturen ontvangstbevestiging
# 3               4634935        560530                 fase aanvraag ontvangen
# 4               4634935        560530             aanvrager is belanghebbende
# ..                  ...           ...                                     ...
# 995              560521        560532              verlengen proceduretermijn
# 996              560521        560532            registratie datum publicatie
# 997              560521        560532                   WAW vergunningsaspect
# 998              560521        560532       behandelen deelzaken volledigheid
# 999              560521        560532                   procedure verandering
#
#      concept:name            question         dateFinished   action_code  \
# 0    01_HOOFD_010               EMPTY  2013-01-10 12:07:35  01_HOOFD_010
# 1    01_HOOFD_011               False  2013-01-10 12:07:35  01_HOOFD_011
# 2    01_HOOFD_020                True  2013-01-10 12:07:35  01_HOOFD_020
# 3    01_HOOFD_015               EMPTY  2013-01-10 12:07:35  01_HOOFD_015
# 4      03_GBH_005                True  2013-01-10 12:07:35    03_GBH_005
# ..            ...                 ...                  ...           ...
# 995     06_VD_010               False  2012-04-25 10:43:10     06_VD_010
# 996  01_HOOFD_101  25-4-2012 10:43:07  2012-04-25 10:43:10  01_HOOFD_101
# 997  01_HOOFD_130               False  2012-04-25 10:43:10  01_HOOFD_130
# 998  01_HOOFD_110               EMPTY  2012-06-20 11:42:30  01_HOOFD_110
# 999  01_HOOFD_180               False  2012-06-20 11:42:30  01_HOOFD_180
#
#                        activityNameEN                    planned  \
# 0    register submission date request  2012-03-23 10:21:14+01:00
# 1                OLO messaging active  2012-03-23 10:26:05+01:00
# 2           send confirmation receipt
# 3          phase application received
# 4            applicant is stakeholder
# ..                                ...                        ...
# 995             extend procedure term
# 996     registration date publication
# 997                 WAW permit aspect
# 998       treat subcases completeness  2012-04-26 10:43:07+02:00
# 999                  procedure change
#
#     lifecycle:transition  ...   case:last_phase case:case_type  \
# 0               complete  ...  Zaak afgehandeld         557669
# 1               complete  ...  Zaak afgehandeld         557669
# 2               complete  ...  Zaak afgehandeld         557669
# 3               complete  ...  Zaak afgehandeld         557669
# 4               complete  ...  Zaak afgehandeld         557669
# ..                   ...  ...               ...            ...
# 995             complete  ...  Zaak afgehandeld         557669
# 996             complete  ...  Zaak afgehandeld         557669
# 997             complete  ...  Zaak afgehandeld         557669
# 998             complete  ...  Zaak afgehandeld         557669
# 999             complete  ...  Zaak afgehandeld         557669
#
#                 case:startDate  case:requestComplete case:SUMleges  \
# 0    2012-03-21 00:00:00+01:00                 False
# 1    2012-03-21 00:00:00+01:00                 False
# 2    2012-03-21 00:00:00+01:00                 False
# 3    2012-03-21 00:00:00+01:00                 False
# 4    2012-03-21 00:00:00+01:00                 False
# ..                         ...                   ...           ...
# 995  2012-04-23 00:00:00+02:00                  True      465.7575
# 996  2012-04-23 00:00:00+02:00                  True      465.7575
# 997  2012-04-23 00:00:00+02:00                  True      465.7575
# 998  2012-04-23 00:00:00+02:00                  True      465.7575
# 999  2012-04-23 00:00:00+02:00                  True      465.7575
#
#     case:IDofConceptCase case:termName case:landRegisterID dueDate  dateStop
# 0
# 1
# 2
# 3
# 4
# ..                   ...           ...                 ...     ...       ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 28 columns]

# %%
net, initial_marking, final_marking = pm4py.discover_petri_net_inductive(event_logs[0])
net2, initial_marking2, final_marking2 = pm4py.discover_petri_net_inductive(event_logs[0])

# %%
# source and target: Place or Transition class
[x for x in net2.arcs]
# Out:
# [(230ecec9-f04d-4d18-b3cb-f39f6250e825, '01_HOOFD_809')->p_46,
#  p_45->(617a544a-ea3f-49a6-9520-d3fa76f92ada, '01_HOOFD_440_2'),
#  p_45->(6f18d6a0-7317-416e-b447-cca35461fdc4, '10_UOV_040'),
#  p_45->(ef8f7490-a73e-4aab-aeed-fa37b15e7a2c, '15_NGV_010'),
#  (init_loop_12, None)->p_39,
#  p_45->(ecfeb254-7d62-4a29-ab7d-1eb1b25d833f, '16_LGSD_010'),
#  (10ae8d54-41d4-45ad-813b-6511e73bad49, '06_VD_035')->p_46,
#  p_45->(ab90fb59-8d7f-4936-9fce-d7f849be0725, '01_BB_775'),
#  (eadf1148-b3eb-48dc-98b2-67fa585bf26c, '01_HOOFD_100')->p_42,
#  p_45->(7629c820-f6d2-419a-acf6-eefa1f04cf08, '01_BB_765'),
#  p_45->(a98e0f71-2075-421e-be1d-17f67a76039b, '01_HOOFD_195'),
#  p_9->(22cd1cbf-7877-43ad-8462-986ce37c1a4a, '01_HOOFD_490_5a'),
#  p_45->(8755850e-9134-475e-9e25-20d85b477b6e, '01_HOOFD_110_2'),
#  p_22->(32b72cf7-6674-4389-990a-245bc95065be, '01_HOOFD_012'),
#  p_45->(e6204784-ddf6-4d00-ab00-5dc732421eea, '01_BB_766'),
#  (24434952-3b8d-4120-8d8f-62dd05f09fb1, '10_UOV_030')->p_46,
#  (tauSplit_8, None)->p_35,
#  (b6fedc3e-1555-4bbc-8f63-ef48da8a2a59, '01_HOOFD_250')->p_46,
#  (a98e0f71-2075-421e-be1d-17f67a76039b, '01_HOOFD_195')->p_46,
#  p_12->(7c32fb34-b830-4693-b9d4-7f4c1593c52b, '01_HOOFD_030_1'),
#  p_45->(2fa8863f-2324-49e8-b249-dc4c59e41be3, '01_BB_770'),
#  (tauSplit_8, None)->p_29,
#  (b51c4c5b-a002-48e7-9e54-24efa51db837, '07_OPS_080_1')->p_46,
#  (4789cd38-becc-4ce4-bc89-454a199fa843, '01_HOOFD_120')->p_46,
#  (ce82ff2e-1655-496f-9dc8-edc12c733949, '01_HOOFD_530')->p_46,
#  p_45->(83b5fdfe-6fc4-4d33-8c9d-7a778ede7f35, '01_HOOFD_375'),
#  p_45->(bd100b83-43f3-4575-bd74-7c6a9a3fbeab, '01_HOOFD_814'),
#  p_45->(d11c803b-ef83-4538-9387-d0a740e5314f, '04_BPT_020'),
#  (5906741d-a66c-4887-8ea7-e8749122d10c, '01_HOOFD_130')->p_46,
#  p_45->(b6983cb7-7992-4622-94cc-283dae6b4272, '08_AWB45_020_2'),
#  p_45->(2a1f34b3-dc54-4acd-9af6-001d5b163670, '01_HOOFD_820'),
#  (6f18d6a0-7317-416e-b447-cca35461fdc4, '10_UOV_040')->p_46,
#  (tauSplit_5, None)->p_18,
#  p_45->(fe82a57f-d501-44d4-b880-3d3944827c64, '01_BB_540'),
#  p_45->(acf1a8a6-a9f3-4589-87ff-3ef455601da8, '01_HOOFD_515'),
#  (ef8f7490-a73e-4aab-aeed-fa37b15e7a2c, '15_NGV_010')->p_46,
#  (ed2090e3-f61c-488a-add5-253ccea6d0e2, '01_HOOFD_010')->p_9,
#  p_5->(2937e32a-64d7-40f3-8208-b190721fafad, '01_HOOFD_030_2'),
#  (3ee1f7a6-e7c6-40a6-9727-e6591f4d9b67, '01_HOOFD_250_1')->p_46,
#  p_45->(47cd2763-ad79-4922-8442-b03837f80dff, '01_HOOFD_510_2'),
#  p_40->(skip_24, None),
#  (85d826d6-b538-4d57-bb3a-1278e73594c7, '06_VD_060_3')->p_46,
#  p_17->(tauJoin_3, None),
#  p_45->(fd163113-68c3-456d-9a67-4b5b12898de4, '08_AWB45_020_1'),
#  p_45->(6ae83c6e-72f7-48ea-a99e-bd40808da2d2, '01_OLO_160'),
#  (tauSplit_5, None)->p_20,
#  p_45->(4b2450cb-382c-41ff-a4de-7b22c9461660, '01_HOOFD_491'),
#  (init_loop_14, None)->p_41,
#  (skip_24, None)->p_36,
#  p_45->(7081a243-50e6-4370-8ec8-df15294605c0, '01_HOOFD_811'),
#  p_45->(ce3d7859-ff65-4460-8ea6-ddb449afaaac, '01_HOOFD_510_1'),
#  p_45->(c491cb7c-8f2c-4411-a4d5-a6c225616372, '01_HOOFD_190_1'),
#  p_15->(tauJoin_3, None),
#  (b24da683-26b0-448d-b203-67a5fa7885fb, '06_VD_060_1')->p_46,
#  (cd2fb34d-dda8-4f25-9bcc-662fce0003d9, '01_HOOFD_510_4')->p_37,
#  p_45->(e5fee7e8-7e48-471a-9823-366955492940, '10_UOV_050_2'),
#  p_45->(42b193eb-e067-4dfe-8ce7-b67f7e4dcb21, '01_HOOFD_061'),
#  (acd91908-33c9-4170-a4d0-1d59e4b401e5, '01_HOOFD_101b')->p_46,
#  (7feb512b-1efc-469f-af21-0d87cf239469, '07_OPS_060_2')->p_46,
#  p_45->(4927f95a-7d3e-4c35-ac48-b74f99ad8ffa, '01_HOOFD_460'),
#  (834f3ca0-708f-4ced-a020-32db7ecf1cf2, '01_HOOFD_490_4')->p_46,
#  (fe1fbe03-f91b-4502-a20f-a8994364ade7, '01_HOOFD_330')->p_46,
#  (tauSplit_8, None)->p_31,
#  p_44->(skip_19, None),
#  p_45->(0f5c4be8-a8b7-4378-9cd4-1e739fbf5a8a, '01_HOOFD_101'),
#  (3abeee11-a780-4512-8bec-59dc6437eb95, '01_HOOFD_440_1')->p_46,
#  (890b6b00-c3f6-4491-a7a1-31e891ab5a25, '07_OPS_060_1')->p_46,
#  p_45->(1a3fe566-580e-492d-bb2f-e421d5ef78f4, '01_HOOFD_490_1'),
#  p_13->(tauJoin_3, None),
#  (tauSplit_5, None)->p_14,
#  (tauSplit_8, None)->p_25,
#  (fd163113-68c3-456d-9a67-4b5b12898de4, '08_AWB45_020_1')->p_46,
#  p_45->(4137dbe3-10f0-4294-8e07-5d9cda913c54, '01_HOOFD_196'),
#  p_35->(ba01bfd3-25d6-48f4-9d91-a1f4a2443863, '05_EIND_010'),
#  (2937e32a-64d7-40f3-8208-b190721fafad, '01_HOOFD_030_2')->p_6,
#  p_45->(211ab18c-0801-47fc-9331-26a324a02a9d, '01_HOOFD_445'),
#  (6ae83c6e-72f7-48ea-a99e-bd40808da2d2, '01_OLO_160')->p_46,
#  p_45->(c3c4ebf8-49ce-46ba-be7f-41672afae675, '01_HOOFD_270'),
#  p_38->(88d5f5e4-5d51-4c1a-a8f2-5a7643c4969f, '06_VD_060_2'),
#  (0d580d00-f396-4294-9811-29403561206e, '01_HOOFD_446')->p_46,
#  p_8->(tauJoin_3, None),
#  (2d3c9631-f489-45cc-a0f2-02c138cfd0c0, '01_HOOFD_380')->p_46,
#  p_45->(aa25e925-6f9d-40dc-a65f-f06f970df80b, '10_UOV_180'),
#  (174bad9c-efe0-43dd-b66d-14e2ebf91a7f, '01_HOOFD_430')->p_46,
#  p_36->(tauJoin_3, None),
#  (f76ef9b3-6c60-4012-81ac-03869a7694d3, '09_AWB45_005')->p_46,
#  p_42->(skip_21, None),
#  p_45->(e46704c3-13a5-4157-9f28-f63024c06637, '07_OPS_050'),
#  (95202c05-60f6-40b9-b241-1ae8c1c64707, '01_HOOFD_495')->p_46,
#  p_45->(6bb4cd36-2241-4710-a1fc-eb963f7f21ee, '06_VD_010'),
#  (9c2d7da2-d356-4fa3-8caa-d78210f09ed0, '01_HOOFD_065_0')->p_46,
#  p_45->(e97fe8c7-c973-4068-a85e-6685b118e799, '01_HOOFD_110_1'),
#  (2e232fc4-ee5c-457b-8592-6f8972178dca, '08_AWB45_030')->p_46,
#  (46034d66-d247-4183-957d-a92036cb883b, '08_AWB45_010')->p_46,
#  p_45->(aac8b58d-bfb3-4a03-8156-94fcb4428f97, '13_CRD_010'),
#  p_43->(skip_16, None),
#  (42b193eb-e067-4dfe-8ce7-b67f7e4dcb21, '01_HOOFD_061')->p_46,
#  (6bb4cd36-2241-4710-a1fc-eb963f7f21ee, '06_VD_010')->p_46,
#  p_45->(e8e25274-6a95-4a83-808b-560daea5a641, '01_HOOFD_510_0'),
#  p_9->(skip_4, None),
#  p_16->(63151a20-110d-413c-86c4-a127216204dd, '03_GBH_005'),
#  p_45->(7eef4014-36f8-40f5-bacc-456539d063ce, '10_UOV_210'),
#  (b1d2a012-8282-4e79-aa73-e9391c40519f, '01_HOOFD_815')->p_46,
#  (e46704c3-13a5-4157-9f28-f63024c06637, '07_OPS_050')->p_46,
#  p_45->(c1e1b7a5-7904-48f9-8bf6-5e6e4531f791, '01_HOOFD_050'),
#  (684db924-ac92-4b68-a56f-5c8201e18876, '06_VD_030_1')->p_46,
#  p_45->(809a8156-4cfe-4cdb-82b8-c1f2404e0a6c, '01_HOOFD_370'),
#  (skip_25, None)->p_35,
#  p_45->(deb84659-5c40-4138-889e-49884e42ca6c, '07_OPS_010'),
#  p_45->(e8be7fe3-5bbc-46e0-93c0-6fb92f3fb8f2, '07_OPS_071'),
#  (d7375ea9-2926-444f-8a69-1f9e17ebecde, '01_HOOFD_516')->p_46,
#  p_45->(07917b0a-f374-46b3-bc42-182b9160f18e, '01_HOOFD_465'),
#  (a20d394a-ac7b-408b-8868-5c29df6ab2d5, '01_HOOFD_011')->p_15,
#  (88d5f5e4-5d51-4c1a-a8f2-5a7643c4969f, '06_VD_060_2')->p_37,
#  p_45->(da6c5841-5980-49a2-80ab-90fb7b224c0c, '01_OLO_190'),
#  (ed2090e3-f61c-488a-add5-253ccea6d0e2, '01_HOOFD_010')->p_7,
#  p_27->(2dc1353d-62ad-46b2-b74c-138e2a73c451, '01_HOOFD_020'),
#  (skip_16, None)->p_42,
#  p_45->(2d1d4814-6746-41ad-850c-d8d5408ad663, '01_HOOFD_250_2'),
#  (aac8b58d-bfb3-4a03-8156-94fcb4428f97, '13_CRD_010')->p_46,
#  p_45->(24434952-3b8d-4120-8d8f-62dd05f09fb1, '10_UOV_030'),
#  p_14->(a20d394a-ac7b-408b-8868-5c29df6ab2d5, '01_HOOFD_011'),
#  p_45->(5906741d-a66c-4887-8ea7-e8749122d10c, '01_HOOFD_130'),
#  (skip_23, None)->p_39,
#  (0f534319-67a5-484a-af81-7842ad0bd46f, '08_AWB45_005')->p_46,
#  (0f0c60c9-bfa6-4dce-8170-0e07ed54126c, '01_HOOFD_500')->p_46,
#  (aa25e925-6f9d-40dc-a65f-f06f970df80b, '10_UOV_180')->p_46,
#  p_43->(eadf1148-b3eb-48dc-98b2-67fa585bf26c, '01_HOOFD_100'),
#  p_45->(2d3c9631-f489-45cc-a0f2-02c138cfd0c0, '01_HOOFD_380'),
#  (skip_4, None)->p_11,
#  (7eef4014-36f8-40f5-bacc-456539d063ce, '10_UOV_210')->p_46,
#  p_45->(c7655bd3-6f0f-438e-8d14-cca9d9c331f0, '06_VD_030_4'),
#  p_42->(skip_22, None),
#  p_22->(skip_7, None),
#  (c1e1b7a5-7904-48f9-8bf6-5e6e4531f791, '01_HOOFD_050')->p_46,
#  (tauJoin_3, None)->sink,
#  (tauSplit_5, None)->p_16,
#  (deb84659-5c40-4138-889e-49884e42ca6c, '07_OPS_010')->p_46,
#  (e8be7fe3-5bbc-46e0-93c0-6fb92f3fb8f2, '07_OPS_071')->p_46,
#  p_45->(d7375ea9-2926-444f-8a69-1f9e17ebecde, '01_HOOFD_516'),
#  (e97fe8c7-c973-4068-a85e-6685b118e799, '01_HOOFD_110_1')->p_46,
#  (07917b0a-f374-46b3-bc42-182b9160f18e, '01_HOOFD_465')->p_46,
#  p_45->(10ae8d54-41d4-45ad-813b-6511e73bad49, '06_VD_035'),
#  p_45->(9c2570d8-fa4e-4791-b13f-b0a5f3d05206, '08_AWB45_040'),
#  p_37->(init_loop_12, None),
#  (da6c5841-5980-49a2-80ab-90fb7b224c0c, '01_OLO_190')->p_46,
#  (809a8156-4cfe-4cdb-82b8-c1f2404e0a6c, '01_HOOFD_370')->p_46,
#  p_45->(b51c4c5b-a002-48e7-9e54-24efa51db837, '07_OPS_080_1'),
#  (2dc1353d-62ad-46b2-b74c-138e2a73c451, '01_HOOFD_020')->p_28,
#  (598cab00-3f03-402c-b3ca-d5abc2cbc40f, '01_HOOFD_065_2')->p_8,
#  p_45->(ce82ff2e-1655-496f-9dc8-edc12c733949, '01_HOOFD_530'),
#  (e8e25274-6a95-4a83-808b-560daea5a641, '01_HOOFD_510_0')->p_46,
#  p_45->(4789cd38-becc-4ce4-bc89-454a199fa843, '01_HOOFD_120'),
#  (2d1d4814-6746-41ad-850c-d8d5408ad663, '01_HOOFD_250_2')->p_46,
#  (skip_22, None)->p_40,
#  (skip_21, None)->p_41,
#  (skip_7, None)->p_24]

# %%
def save_bpmn(dataset):
    # extract the dataset name
    dataset_name = re.match('../datasets/(.+).csv', dataset).groups()[0]
    # read the event log
    event_log = load_event_log(dataset, n_rows=1000)
    # discover a process model
    pm4py.discover_petri_net_inductive(event_log)
    # convert it from petri nets to a process tree
    pt = pm4py.convert.convert_to_process_tree(net, initial_marking, final_marking)
    # convert the process tree to a bpmn
    bpmn = pm4py.convert.convert_to_bpmn(pt)
    # save it
    print('../plots/' + dataset_name + '.bpmn')
    pm4py.write.write_bpmn(bpmn, '../plots/' + dataset_name + '.bpmn')

datasets = glob.glob('../datasets/*.csv', recursive=False)
[save_bpmn(d) for d in datasets]
# Out:
# Reading ../datasets/BPIC2015_2.csv
# ../plots/BPIC2015_2.bpmn
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/graphviz/backend/execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80     else:
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#      82 except OSError as e:
#
# File /opt/conda/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /opt/conda/lib/python3.10/subprocess.py:969, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     966             self.stderr = io.TextIOWrapper(self.stderr,
#     967                     encoding=encoding, errors=errors)
# --> 969     self._execute_child(args, executable, preexec_fn, close_fds,
#     970                         pass_fds, cwd, env,
#     971                         startupinfo, creationflags, shell,
#     972                         p2cread, p2cwrite,
#     973                         c2pread, c2pwrite,
#     974                         errread, errwrite,
#     975                         restore_signals,
#     976                         gid, gids, uid, umask,
#     977                         start_new_session)
#     978 except:
#     979     # Cleanup if the child failed starting.
#
# File /opt/conda/lib/python3.10/subprocess.py:1845, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1844         err_msg = os.strerror(errno_num)
# -> 1845     raise child_exception_type(errno_num, err_msg, err_filename)
#    1846 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: PosixPath('dot')
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Input In [68], in <cell line: 17>()
#      14     pm4py.write.write_bpmn(bpmn, '../plots/' + dataset_name + '.bpmn')
#      16 datasets = glob.glob('../datasets/*.csv', recursive=False)
# ---> 17 [save_bpmn(d) for d in datasets]
#
# Input In [68], in <listcomp>(.0)
#      14     pm4py.write.write_bpmn(bpmn, '../plots/' + dataset_name + '.bpmn')
#      16 datasets = glob.glob('../datasets/*.csv', recursive=False)
# ---> 17 [save_bpmn(d) for d in datasets]
#
# Input In [68], in save_bpmn(dataset)
#      12 # save it
#      13 print('../plots/' + dataset_name + '.bpmn')
# ---> 14 pm4py.write.write_bpmn(bpmn, '../plots/' + dataset_name + '.bpmn')
#
# File /opt/conda/lib/python3.10/site-packages/pm4py/write.py:181, in write_bpmn(bpmn_graph, file_path, enable_layout)
#     179 if enable_layout:
#     180     from pm4py.objects.bpmn.layout import layouter
# --> 181     bpmn_graph = layouter.apply(bpmn_graph)
#     182 from pm4py.objects.bpmn.exporter import exporter
#     183 exporter.apply(bpmn_graph, file_path)
#
# File /opt/conda/lib/python3.10/site-packages/pm4py/objects/bpmn/layout/layouter.py:49, in apply(bpmn_graph, variant, parameters)
#      30 def apply(bpmn_graph, variant=DEFAULT_VARIANT, parameters=None):
#      31     """
#      32     Layouts a BPMN graph (inserting the positions of the nodes and the layouting of the edges)
#      33
#    (...)
#      47         BPMN graph with layout information
#      48     """
# ---> 49     return exec_utils.get_variant(variant).apply(bpmn_graph, parameters=parameters)
#
# File /opt/conda/lib/python3.10/site-packages/pm4py/objects/bpmn/layout/variants/graphviz.py:116, in apply(bpmn_graph, parameters)
#     113 for tup in graph_edges:
#     114     viz.edge(nodes_dict[tup[0]], nodes_dict[tup[1]])
# --> 116 gsave.save(viz, filename_svg.name)
#     118 nodes_pos = {}
#     120 content = open(filename_svg.name, "r").read()
#
# File /opt/conda/lib/python3.10/site-packages/pm4py/visualization/common/save.py:31, in save(gviz, output_file_path)
#      20 def save(gviz, output_file_path):
#      21     """
#      22     Save the diagram
#      23
#    (...)
#      29         Path where the GraphViz output should be saved
#      30     """
# ---> 31     render = gviz.render(cleanup=True)
#      32     shutil.copyfile(render, output_file_path)
#
# File /opt/conda/lib/python3.10/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/graphviz/rendering.py:122, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
# --> 122 rendered = self._render(*args, **kwargs)
#     124 if cleanup:
#     125     log.debug('delete %r', filepath)
#
# File /opt/conda/lib/python3.10/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/graphviz/backend/rendering.py:324, in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     320     raise exceptions.FileExistsError(f'output file exists: {os.fspath(outfile)!r}')
#     322 cmd += args
# --> 324 execute.run_check(cmd,
#     325                   cwd=filepath.parent if filepath.parent.parts else None,
#     326                   quiet=quiet,
#     327                   capture_output=True)
#     329 return os.fspath(outfile)
#
# File /opt/conda/lib/python3.10/site-packages/graphviz/backend/execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute PosixPath('dot'), make sure the Graphviz executables are on your systems' PATH
